# %%
from IPython.display import Image,display
display(Image(filename='intro.JPG'))

# %% [markdown]
# ## Conversion from power law/Pareto to Gaussian:

# %%
from IPython.display import Image,display
display(Image(filename='conversion.JPG'))

# %% [markdown]
# ## Steps:
# * calculate the lambda of the perito distribution X=(x1,x2,....xn) by using the function box-cox
# * Use this lambda to convert it into Gaussian Distribution

# %%
from IPython.display import Image,display
display(Image(filename='conversion2.JPG'))

# %%
from IPython.display import Image,display
display(Image(filename='conversion1.JPG'))

# %%
from IPython.display import Image,display
display(Image(filename='conversion3.JPG'))

# %%
from IPython.display import Image,display
display(Image(filename='conversion4.JPG'))

# %% [markdown]
# * In the above figure in the upper diagram without box cox transformation there is deviation in the straight line so distribution on X axis and distribution on Y axis dont lie on the same family
# * But in the lower diagram after box cox transformation there is no deviation of points so distribution on X asix and distribution on Y axis lie on the same family or both distribution follow Gaussian Distribution

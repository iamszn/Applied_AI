# %% [markdown]
# ## 11.12 - Discrete and Continuous Uniform distributions

# %%
from IPython.display import Image,display
display(Image(filename='pmf_discrete.JPG'))

# %%
from IPython.display import Image,display
display(Image(filename='example.JPG'))

# %%
from IPython.display import Image,display
display(Image(filename='param_discrete.JPG'))

# %%
from IPython.display import Image,display
display(Image(filename='pdf_continuous.JPG'))

# %%
from IPython.display import Image,display
display(Image(filename='param_continuous.JPG'))

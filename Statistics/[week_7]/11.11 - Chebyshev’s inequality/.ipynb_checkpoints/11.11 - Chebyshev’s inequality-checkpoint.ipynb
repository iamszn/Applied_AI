# %% [markdown]
# ## 11.11 - Chebyshev’s inequality

# %%
from IPython.display import Image,display
display(Image(filename='sallary.JPG'))

# %% [markdown]
# ## Discussion:
# * Suppose we have a list of sallarys of individuals and it follow certain distribution but we dont know the distribution.But we know the mean and variance and standard deviation of the sallarys.If mean is 40K and stabdard deviation is 20k then
# * what percentage of individual have the sallary in the range of 10K and 40K?[Note If the sallary followed gussian distribution then we can use 68-95-97]

# %%
from IPython.display import Image,display
display(Image(filename='chebyshev1.JPG'))

# %%
from IPython.display import Image,display
display(Image(filename='chebyshev2.JPG'))

# %%
from IPython.display import Image,display
display(Image(filename='sallary_sol.JPG'))

# %% [markdown]
# ## Log Normal Distribution:

# %%
from IPython.display import Image,display
display(Image(filename='intro.jpg'))

# %%
from IPython.display import Image,display
display(Image(filename='example.jpg'))

# %% [markdown]
# ## Discussion:
# * In internet discussion forum maximum no of comments has small length while very few no of comments has large length
# * similarly in online article large no of people spend vey few time while only few spend large time which is also log normal  distribution

# %%
from IPython.display import Image,display
display(Image(filename='test.jpg'))

# %% [markdown]
# ## Discussion:
# * Given a random variable X having value x1,x2,x3......xn having mean and variance  can be checked if it follows log normal distribution or not
# * take the logaramathic of each value of x
# * Now plot these value against the standard gausian value using QQ plot
# * If these value lie on the straight line then random variable X  are Gaussian distribution
# * If it is gaussian distribution then X follows log normal distribution

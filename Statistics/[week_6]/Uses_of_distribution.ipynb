# %% [markdown]
# ## How distribution are used?

# %%
from IPython.display import display,Image
display(Image(filename='uses1.JPG'))

# %% [markdown]
# ## Discussion:
# * Suppose you work in a XYZ company and you are assigned to order the t-shirt for 100k employee who works there.There are four possible sizes of t-shirt and they are S,M,L,XL.
# * XL=Employee whose height is greater or equal to 180cm
# * L=employee whose height is greater than 160cm and smaller than 180cm

# %% [markdown]
# ## Q.How many XL t-shirt should you order?

# %%
from IPython.display import display,Image
display(Image(filename='uses2.JPG'))

# %% [markdown]
# ## Process:
# * 1.Collect the height of 500 random employees
# * 2.Suppose that height of people is Gaussian distributed and from data we can calculate mean and standard deviation then from this information we can plot CDF

# %%
from IPython.display import display,Image
display(Image(filename='uses3.JPG'))

# %% [markdown]
# ## Discussion:
# * From this CDF we can find the probability of people whose height is greater than 180cm and that is 1%
# * 1% i.e. we have to order 100 XL t-shirt

# %%
from IPython.display import display,Image
display(Image(filename='uses4.JPG'))

# %% [markdown]
# * Q.how many employee make sallary between 50k and 70K?

# %% [markdown]
# ## Discussion:
# * If  sallary follow Gaussian distribution then we can draw CDf and from CDF we can find the no of people whose sallary is between 50K and 70K

# %% [markdown]
# ## Q.How to find if the sallary follow gaussian Distribution or not?
# * By using QQ plot ( comparing sallary with normal distribution )
